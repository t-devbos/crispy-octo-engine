# %% [markdown]
# # In een_package staan nu 3 files, dat zijn greet.py, bye.py en money.py en een data file met orders.csv
# We gaan deze importeren en direct runnen. Importeren is het binnenhalen van de tools van de module.

# %% [markdown]
# ### a) import zonder init of main
#
# Probeer eerst import greet te doen, welke error krijg je?
# Probeer dan from een_package import greet , wat gebeurt er nu?
# Als laatste, probeer de hello functie aan te roepen van greet, hoe doe je dat?

# %%
#schrijf hier voor opdracht a)
from een_package.greet import greet

greet()
# Out:
# 'greetings everyone'

# %% [markdown]
# ### b) `__init__.py`
#
# Maak een `__init__.py` aan ín de map van een_package. Hou hem nog leeg.
# Werkt het aanroepen van de hello functie van a) nog? Werkt het volgende ook?
#
# __from een_package import Money__
#
# Kijk naar concepts.ipynb en schrijf de imports en `__all__.py` in de init file.
# Probeer dan:
#
# __from een_package import *__
#
# __greet()__

# %%
#schrijf hier voor opdracht b)
from een_package.money import Money
print(Money(100))
# Out:
# EUR 1.00

# %% [markdown]
# ### c) `__main__.py`
#
# Als je het package wilt laten draaien, maak dan een __main__.py aan. Zet hierin het volgende:
#
# from een_package import greet, bye, Money
#
# print(greet())
# print(bye())
# print("Totaal:", Money(10).cents)

# %% [markdown]
# Open nu een nieuwe terminal en ga met `cd` naar `een_project`
#
# Als je hier bent, schrijf dan in de terminal:
# python -m een_package

# %% [markdown]
# ## Extra: maak een nieuwe file aan waarin je probeert te importeren vanuit een andere map dan een_project.
# Maak gebruik van from pathlib import Path
